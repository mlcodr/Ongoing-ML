# %%
# importing libs 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import sklearn 
import datetime
print(f"Last Updated: {datetime.datetime.now()}")
# Out:
# Last Updated: 2026-03-04 16:42:20.725559

# %%
## Importing the dataset 
heart_disease  = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")

# %%
heart_disease.tail(5)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %% [markdown]
# ![image.png](attachment:be088072-0565-4946-affa-cbd5637d9320.png)

# %%
# Splitting the data into features (X) and labels (y)
X = heart_disease.drop("target",axis = 1)
y = heart_disease["target"]

# %%
X.shape,y.shape
# Out:
# ((303, 13), (303,))

# %%
y.value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %% [markdown]
# Now let's split our data into training and test sets, we'll use an 80/20 split (80% of samples for training and 20% of samples for testing).

# %%
## Splitting the data into training and test sets 
from sklearn.model_selection import train_test_split
X_train,y_train,X_test,y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((242, 13), (61, 13), (242,), (61,))

# %%
## 80% of the data used for training the model 
X.shape[0] * 0.8
# Out:
# 242.4

# %%
X.shape[0] * 0.2
# Out:
# 60.6

# %% [markdown]
# ![image.png](attachment:2d76abdd-38f8-4b11-bd71-ec009570c099.png)|

# %%
# Import car-sales-extended.csv
car_sales = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales-extended.csv")
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price             int64
# dtype: object

# %%
x = car_sales.drop("Price",axis = 1)
Y = car_sales["Price"]
x_train,Y_train,x_test,Y_test = train_test_split(x,Y,test_size=0.2)

# %%
# Try to predict with random forest on price column(doesn't work)
from sklearn.ensemble import RandomForestRegressor 
model = RandomForestRegressor
model.fit(x_train,Y_train)
model.score(x_test,Y_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9960\2335552703.py in ?()
#       1 # Try to predict with random forest on price column(doesn't work)
#       2 from sklearn.ensemble import RandomForestRegressor
#       3 model = RandomForestRegressor
# ----> 4 model.fit(x_train,Y_train)
#       5 model.score(x_test,Y_test)
#
# ~\Desktop\Miniconda_Projects\env\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1354                 fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1355             )
#    1356
#    1357             if not global_skip_validation and not partial_fit_and_fitted:
# -> 1358                 estimator._validate_params()
#    1359
#    1360             with config_context(
#    1361                 skip_parameter_validation=(
#
# ...

# %% [markdown]
# Machine learning model prefer to work with numerical numbers than text
# so we'll have to convert the non-numerical features into numbers first
# The process of tuning categorical features into numbers is often referred to as **encoding**
