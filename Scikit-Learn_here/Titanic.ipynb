# %%
import pandas as pd 
import numpy as np 
# %matplotlib inline 
import matplotlib.pyplot as plt 
import sklearn 
import datetime 
print(f"Last Updated: {datetime.datetime.now()}")
# Out:
# Last Updated: 2026-03-04 07:00:47.368585

# %% [markdown]
# ### Getting the data ready

# %%
# Importing Dataset 
# !pip install kagglehub
import kagglehub
import pandas as pd
import os

# 1. Download the Titanic dataset files from Kaggle
path = kagglehub.dataset_download("yasserh/titanic-dataset")

# 2. Identify the CSV file in the downloaded folder
# The folder usually contains one file: 'Titanic-Dataset.csv'
file_name = "Titanic-Dataset.csv"
full_path = os.path.join(path, file_name)

# 3. Load the data into your variable 'titanic'
titanic = pd.read_csv(full_path)

# %% [markdown]
# Data doesn't always come ready to use with a Scikit-Learn machine learning model.
#
# Three of the main steps you'll often have to take are:
# * Splitting the data into features (usually X) and labels (usually y).
# * Splitting the data into training and testing sets (and possibly a validation set).
# * Filling (also called imputing) or disregarding missing values.
# * Converting non-numerical values to numerical values (also call feature encoding).

# %%
# Splitting the data into X & y
titanic.tail(50)
# Out:
#      PassengerId  Survived  Pclass  \
# 841          842         0       2
# 842          843         1       1
# 843          844         0       3
# 844          845         0       3
# 845          846         0       3
# 846          847         0       3
# 847          848         0       3
# 848          849         0       2
# 849          850         1       1
# 850          851         0       3
# 851          852         0       3
# 852          853         0       3
# 853          854         1       1
# 854          855         0       2
# 855          856         1       3
# 856          857         1       1
# 857          858         1       1
# 858          859         1       3
# 859          860         0       3
# 860          861         0       3
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# ...

# %%
# Splitting the data into features (X) and labels (y)
X = heart_disease.drop("target",axis = 1)
y = heart_disease["target"]

# %%
X.tail(3), y.iloc[25]
# Out:
# (     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
#  300   68    1   0       144   193    1        1      141      0      3.4
#  301   57    1   0       130   131    0        1      115      1      1.2
#  302   57    0   1       130   236    0        0      174      0      0.0
#
#       slope  ca  thal
#  300      1   2     3
#  301      1   1     3
#  302      1   1     2  ,
#  np.int64(1))

# %%
X.shape, y.shape
# Out:
# ((303, 13), (303,))
