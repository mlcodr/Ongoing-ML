# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import datetime
print(f"Last Updated: {datetime.datetime.now()}")
# Out:
# Last Updated: 2025-12-23 17:35:56.275310

# %% [markdown]
# ## Viewing and Selecting Data

# %%
car_sales = pd.read_csv("D:\Olympiad\CSV FILES\car-sales.csv")
car_sales
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\O'
# <>:1: SyntaxWarning: invalid escape sequence '\O'
# C:\Users\Mr.Brownie\AppData\Local\Temp\ipykernel_12688\280369779.py:1: SyntaxWarning: invalid escape sequence '\O'
#   car_sales = pd.read_csv("D:\Olympiad\CSV FILES\car-sales.csv")
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.head(5)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail(5)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
rides = {"Ride Name": ["Titan","New Texas Giant","Shackleton","Batman","Mr Freeze","Shockwave"],
        "Invertions" : [4,0,5,1,4,7],
        "Top Speed (km/h)" : [50,45,60,65,80,100],
        "Height" : [245,153,145,230,250,180]}
df = pd.DataFrame(data=rides).sort_values(by="Top Speed (km/h)")

# %%
df
# Out:
#          Ride Name  Invertions  Top Speed (km/h)  Height
# 1  New Texas Giant           0                45     153
# 0            Titan           4                50     245
# 2       Shackleton           5                60     145
# 3           Batman           1                65     230
# 4        Mr Freeze           4                80     250
# 5        Shockwave           7               100     180

# %%
print(df.loc[2]["Invertions"])
# Out:
# 5

# %%
print(df.loc[0])
# Out:
# Ride Name           Titan
# Invertions              4
# Top Speed (km/h)       50
# Height                245
# Name: 0, dtype: object

# %%
print(df.iloc[0])
# Out:
# Ride Name           New Texas Giant
# Invertions                        0
# Top Speed (km/h)                 45
# Height                          153
# Name: 1, dtype: object

# %%
## In short loc() uses the location of the item.
## iloc() also uses the location of the item but based on the index

# %%
# Create a simple Series
animals = pd.Series(["Cat","Dog","Doel","Eagle","Magpie","Parrot"],
                   index = [0,2,1,5,6,4])
animals
# Out:
# 0       Cat
# 2       Dog
# 1      Doel
# 5     Eagle
# 6    Magpie
# 4    Parrot
# dtype: object

# %%
# Select all indexes with 3
animals.loc[1]
# Out:
# 'Doel'

# %%
animals.iloc[1]
# Out:
# 'Dog'

# %%
car_sales.sort_values(["Odometer (KM)"])
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 3     BMW  Black          11179      5  $22,000.00
# 9  Nissan  White          31600      4   $9,700.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 1   Honda    Red          87899      4   $5,000.00
# 5  Toyota  Green          99213      4   $4,500.00
# 0  Toyota  White         150043      4   $4,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.loc[8]
# Out:
# Make                Toyota
# Colour               White
# Odometer (KM)        60000
# Doors                    4
# Price            $6,250.00
# Name: 8, dtype: object

# %%
car_sales.iloc[8]
# Out:
# Make                Toyota
# Colour               White
# Odometer (KM)        60000
# Doors                    4
# Price            $6,250.00
# Name: 8, dtype: object

# %%
# We can also do slicing with loc and iloc

# %%
car_sales.loc[2:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales.iloc[2:5]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[:,'Colour']
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
# Select cars with over 100,000 on the Odometer
car_sales[car_sales['Colour']=="Black"]
# Out:
#   Make Colour  Odometer (KM)  Doors       Price
# 3  BMW  Black          11179      5  $22,000.00

# %%
car_sales[car_sales['Doors'] == 3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales[car_sales['Odometer (KM)']<50000]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 6   Honda   Blue          45698      4   $7,500.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales[car_sales['Colour']=="Black"]
# Out:
#   Make Colour  Odometer (KM)  Doors       Price
# 3  BMW  Black          11179      5  $22,000.00

# %%
# Select cars with over 100,000 on the Odometer
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales[car_sales['Make'] == "BMW"]
# Out:
#   Make Colour  Odometer (KM)  Doors       Price
# 3  BMW  Black          11179      5  $22,000.00

# %%
car_sales[car_sales['Make'] == "BMW"]
# Out:
#   Make Colour  Odometer (KM)  Doors       Price
# 3  BMW  Black          11179      5  $22,000.00

# %%
car_sales[car_sales['Make'] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
animals.iloc[:3]
# Out:
# 0     Cat
# 2     Dog
# 1    Doel
# dtype: object

# %%
car_sales[car_sales['Odometer (KM)']>10000]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
## pd.crosstab() is a great way to view two different columns together and compare them.
pd.crosstab(car_sales['Make'],car_sales['Price'])
# Out:
# Price   $22,000.00  $3,500.00  $4,000.00  $4,500.00  $5,000.00  $6,250.00  \
# Make
# BMW              1          0          0          0          0          0
# Honda            0          0          0          0          1          0
# Nissan           0          1          0          0          0          0
# Toyota           0          0          1          1          0          1
#
# Price   $7,000.00  $7,500.00  $9,700.00
# Make
# BMW             0          0          0
# Honda           1          1          0
# Nissan          0          0          1
# Toyota          1          0          0

# %%
## If its needy to compare or view more than 2 columns then we have to use .groupby()
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales.groupby(["Price"]).mean(numeric_only=True)
# Out:
#             Odometer (KM)  Doors
# Price
# $22,000.00        11179.0    5.0
# $3,500.00        213095.0    4.0
# $4,000.00        150043.0    4.0
# $4,500.00         99213.0    4.0
# $5,000.00         87899.0    4.0
# $6,250.00         60000.0    4.0
# $7,000.00         43643.5    3.5
# $7,500.00         45698.0    4.0
# $9,700.00         31600.0    4.0

# %%
# Using Groupby --
df = pd.DataFrame({
    'Gender': ["M","F","M","F","M","F"],
    "City" : ['NY', 'LA', 'NY', 'LA', 'NY','TE'],
    "Sales" : [100,200,250,160,400,180]
})

grouped = df.groupby(["Gender","City"])["Sales"].sum()
print(grouped)
# Out:
# Gender  City
# F       LA      360
#         TE      180
# M       NY      750
# Name: Sales, dtype: int64

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"],car_sales['Price'])
# Out:
# Price   $22,000.00  $3,500.00  $4,000.00  $4,500.00  $5,000.00  $6,250.00  \
# Make
# BMW              1          0          0          0          0          0
# Honda            0          0          0          0          1          0
# Nissan           0          1          0          0          0          0
# Toyota           0          0          1          1          0          1
#
# Price   $7,000.00  $7,500.00  $9,700.00
# Make
# BMW             0          0          0
# Honda           1          1          0
# Nissan          0          0          1
# Toyota          1          0          0

# %%
# Compare car make with number of Doors
df_one = pd.crosstab(car_sales["Make"],car_sales["Colour"])
df_one
# Out:
# Colour  Black  Blue  Green  Red  White
# Make
# BMW         1     0      0    0      0
# Honda       0     2      0    1      0
# Nissan      0     0      0    0      2
# Toyota      0     1      1    0      2

# %%
# To Compare more columns in the context of another column, you can use .groupby()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
plot_one = car_sales['Doors'].plot()

# %%
plot_two = car_sales['Odometer (KM)'].plot()
plot_two
# Out:
# <Axes: >

# %%
car_sales.plot(x="Make", y="Odometer (KM)") ;

# %%
car_sales['Make'].hist()
# Out:
# <Axes: >

# %%
car_sales['Odometer (KM)'].hist()
# Out:
# <Axes: >

# %%
## To Convert a string (Object) datatype to an integer value, use the following code:
### Variable['Object'] = Variable['Object'].str.replace("[\$,]" , "", regex=True).astype(float)
## r is used for raw string and / is used for escaping character.

# %%
car_sales['Price'].plot()
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
# ok but there is and extra zeros in the price column
# Remove 2 extra zeros from the price column by indexing all but the last two digits
car_sales["Price"] = car_sales["Price"].str[:-2].astype(int)
car_sales
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 3
#       1 # ok but there is and extra zeros in the price column
#       2 # Remove 2 extra zeros from the price column (2200000 -> 22000) by indexing all but the last two digits
# ----> 3 car_sales["Price"] = car_sales["Price"].str[:-2].astype(int)
#       4 car_sales
#
# File ~\Desktop\Miniconda_Projects\env\Lib\site-packages\pandas\core\generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# ...

# %%
# ok but there is and extra zeros in the price column
# Remove 2 extra zeros from the price column by indexing all but the last two digits
car_sales["Price"] = car_sales["Price"].str[:-2].astype(int)
car_sales
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 3
#       1 # ok but there is and extra zeros in the price column
#       2 # Remove 2 extra zeros from the price column (2200000 -> 22000) by indexing all but the last two digits
# ----> 3 car_sales["Price"] = car_sales["Price"].str[:-2].astype(int)
#       4 car_sales
#
# File ~\Desktop\Miniconda_Projects\env\Lib\site-packages\pandas\core\generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# ...

# %%
car_sales.info(), car_sales.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 532.0+ bytes
# (None,
#  Make              object
#  Colour            object
#  Odometer (KM)      int64
#  Doors              int64
#  Price            float64
#  dtype: object)

# %%
car_sales['Price'].plot()
# Out:
# <Axes: >
