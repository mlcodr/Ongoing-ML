# %% [markdown]
# # Dot Product ----

# %% [markdown]
# ## Numpy dot product is just element-wise multiplication, also known as Hadamard product

# %%
import numpy as np

# %%
np.random.seed(0)
a_1 = np.random.randint(0,10, size=(2,3))
a_1 , np.ndim(a_1)
# Out:
# (array([[5, 0, 3],
#         [3, 7, 9]], dtype=int32),
#  2)

# %%
a_2 = np.random.randint(0,10, size = (3,2))
a_2 , np.ndim(a_2)
# Out:
# (array([[3, 5],
#         [2, 4],
#         [7, 6]], dtype=int32),
#  2)

# %%
## There are two ways to do the dot operation
## First One using @ and the Second is using the .dot() function

# %%
dot_result = np.dot(a_1,a_2)
dot_result, np.shape(dot_result)
# Out:
# (array([[36, 43],
#         [86, 97]], dtype=int32),
#  (2, 2))

# %% [markdown]
# ### In numpy to perform the dot operation between two array -- there are two tricks
# ![image.png](attachment:835ad30f-b925-48fc-97c6-251b82bd47f9.png)

# %% [markdown]
# ## @ is used for matrix multiplication as matrix is 3-dimentional array

# %% [markdown]
# ![image.png](attachment:b7b60a15-4805-4c8c-a35e-a66833df25ca.png)

# %% [markdown]
# ## Dot Product Practical Example , Nut Butter Sales
