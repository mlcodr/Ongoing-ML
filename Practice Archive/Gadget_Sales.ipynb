# %% [markdown]
# ## Creating our Eclipsee Store Daily Sales Data Sheet

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## In short we're going to make like this one
# ![image.png](attachment:153dbe8a-905e-487f-bee7-3210087cb141.png)

# %%
# Creating the sales amount
np.random.seed(0)
sales_amount = np.random.randint(0,20,size=(5,6))
sales_amount
# Out:
# array([[12, 15,  0,  3,  3,  7],
#        [ 9, 19, 18,  4,  6, 12],
#        [ 1,  6,  7, 14, 17,  5],
#        [13,  8,  9, 19, 16, 19],
#        [ 5, 15, 15,  0, 18,  3]], dtype=int32)

# %%
# Creating Table of the weekly sales
weekly_sales = pd.DataFrame(sales_amount,index=["Sun","Mon","Tues","Wed","Thu"],
                            columns=["Headset","Keyboard","Mouse","iPad","Drone","Camera"])
weekly_sales
# Out:
#       Headset  Keyboard  Mouse  iPad  Drone  Camera
# Sun        12        15      0     3      3       7
# Mon         9        19     18     4      6      12
# Tues        1         6      7    14     17       5
# Wed        13         8      9    19     16      19
# Thu         5        15     15     0     18       3

# %%
# Determining the prices of the gadgets 
prices  = np.array([45,20,10,750,90,300])
prices
# Out:
# array([ 45,  20,  10, 750,  90, 300])

# %%
reshaped_prices = prices.reshape(6,1)
reshaped_prices.shape
# Out:
# (6, 1)

# %%
# Prices_Table
prices_table = pd.DataFrame(gadget_prices.reshape(1,6),index=["Price ($)"],
                      columns=["Headset","Keyboard","Mouse","iPad","Drone","Camera"])
prices_table
# Out:
#            Headset  Keyboard  Mouse  iPad  Drone  Camera
# Price ($)       45        20     10   750     90     300

# %%
# Checking the shapes of the tables
weekly_sales.shape, gadget_prices.shape
# Out:
# ((5, 6), (6,))

# %%
sales = reshaped_prices.T.dot(sales_amount.T)
sales
# Out:
# array([[ 5460,  8105, 13765, 22225,  3195]])

# %%
total_sales = pd.DataFrame(sales,index=["Prices ($)"],
                           columns=["Headset","Keyboard","Mouse","iPad","Drone","Camera"])
total_sales
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 total_sales = pd.DataFrame(sales,index=["Prices ($)"],
#       2                            columns=["Headset","Keyboard","Mouse","iPad","Drone","Camera"])
#       3 total_sales
#
# File ~\Desktop\Miniconda_Projects\env\Lib\site-packages\pandas\core\frame.py:831, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     820         mgr = dict_to_mgr(
#     821             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     822             # attribute "name"
#    (...)    828             copy=_copy,
#     829         )
#     830     else:
# --> 831         mgr = ndarray_to_mgr(
#     832             data,
#     833             index,
#     834             columns,
#     835             dtype=dtype,
#     836             copy=copy,
#     837             typ=manager,
# ...
