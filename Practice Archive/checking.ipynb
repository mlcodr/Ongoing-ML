# %%
print("Heyy Conda!!")
# Out:
# Heyy Conda!!

# %%
print("Heyy Condaaa")
# Out:
# Heyy Condaaa

# %%
print("Meme maker Ayman Siddque")
# Out:
# Meme maker Ayman Siddque

# %% [markdown]
# # Jupyter Notebook Example
# ## Subtitle
# 1. This is item one
# 2. This one is two
# 3. and this is three

# %%
print("Hello Mahfuz")
# Out:
# Hello Mahfuz

# %%
# !jupyter --paths
# Out:
# config:
#     C:\Users\Mr.Brownie\.jupyter
#     C:\Users\Mr.Brownie\AppData\Roaming\Python\etc\jupyter
#     C:\Users\Mr.Brownie\Desktop\Miniconda_Projects\env\etc\jupyter
# data:
#     C:\Users\Mr.Brownie\AppData\Roaming\jupyter
#     C:\Users\Mr.Brownie\AppData\Roaming\Python\share\jupyter
#     C:\Users\Mr.Brownie\Desktop\Miniconda_Projects\env\share\jupyter
# runtime:
#     C:\Users\Mr.Brownie\AppData\Roaming\jupyter\runtime
